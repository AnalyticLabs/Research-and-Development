# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
accuracy = pd.read_csv('accuracy.csv')
precision = pd.read_csv('precision.csv')
f1_score = pd.read_csv('f1_score.csv')

# %%
accuracy
# Out:
#              Random Forest        SVM  Logistic Regression       MLP  \
# train_ratio
# 0.40               0.996849  0.948049             0.984381  0.984381
# 0.60               0.997486  0.953650             0.987332  0.987332
# 0.75               0.997265  0.957690             0.987773  0.987773
# 0.80               0.997587  0.954152             0.988739  0.988739
#
#                   CNN       RNN
# train_ratio
# 0.40         0.949591  0.963467
# 0.60         0.953650  0.965514
# 0.75         0.968468  0.972008
# 0.80         0.948321  0.970440

# %%
accuracy.plot.bar(figsize=(10,6))
plt.title('Accuracy Comparision')
plt.ylabel('accuracy')
plt.tight_layout()

# %%
# precision.index = precision.train_ratio
# precision = precision.drop('train_ratio',axis=1)

precision.plot.bar(figsize=(10,6))
plt.title('Precision Comparision')
plt.ylabel('precision')
plt.tight_layout()

# %%
f1_score.index = f1_score.train_ratio
f1_score = f1_score.drop('train_ratio',axis=1)

f1_score.plot.bar(figsize=(10,6))
plt.title('F1 score Comparision')
plt.ylabel('f1 score')
plt.tight_layout()
